# %% [markdown]
# <center>🌐 Web Data Collection Workshop</center>
# <center>Scraping Static and Dynamic Sites with BeautifulSoup and Selenium</center>
#
# ### 📚 In this workshop you will learn:
# **Static Websites**: Data extraction with `BeautifulSoup` and `requests`
# **Dynamic Websites**: Data extraction with `Selenium`
# **APIs**: Retrieving and sending data
# **Authentication**: Accessing protected pages
#
#
# ### 🔗 Resources:
# [BeautifulSoup Documentation](https://beautiful-soup-4.readthedocs.io/en/latest/)
# [Selenium Documentation](https://selenium-python.readthedocs.io/)

# %% [markdown]
# ## 📦 Installing Required Libraries

# %%
# Install required libraries\n",
# !pip install requests beautifulsoup4 tqdm selenium
# Out:
# Requirement already satisfied: requests in c:\users\amirreza\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\amirreza\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: tqdm in c:\users\amirreza\anaconda3\lib\site-packages (4.65.0)
# Requirement already satisfied: selenium in c:\users\amirreza\anaconda3\lib\site-packages (4.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amirreza\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amirreza\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amirreza\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amirreza\anaconda3\lib\site-packages (from requests) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in c:\users\amirreza\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: colorama in c:\users\amirreza\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: trio~=0.17 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\amirreza\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\amirreza\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\amirreza\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\amirreza\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # 🔍 Part 1: Extracting Data from Static Websites with BeautifulSoup

# %% [markdown]
# ## Sending HTTP Requests with requests

# %%
import requests

# Define the website URL
URL = "https://www.varzesh3.com/"

# Send GET request",
page = requests.get(URL)
#For sites with authentication: page = requests.get(URL, auth=('user', 'pass'))

# Display the first 500 characters of the text response",
print("📄 Page text content (first 500 characters):")
print(page.text[:500])
# Display the first 100 bytes of the binary response
print("💾 Page binary content (first 100 bytes):")
print(page.content[:100])
# Out:
# 📄 Page text content (first 500 characters):
#
#
#
# <!DOCTYPE html>
# <html lang="fa" prefix="og: http://ogp.me/ns#">
# <head>
#     <title>مرجع فوتبال و ورزش | ورزش سه</title>
#     <meta charset="utf-8" />
#
#     <meta name="viewport" content="width=1170" />
#
#     <meta name="description" content="پایگاه اطلاع رسانی ورزشی برای فارسی زبانان كه اخبار حوزه ورزش (فوتبال،والیبال ،بسكتبال و...)ونتایج بازیها و جداول لیگ های ورزشی را بصورت زنده ارائه می کند" />
#
#
#
#
#
# <link href="https://www.varzesh3.com/" rel="canonical" />
#
# <meta pro
# 💾 Page binary content (first 100 bytes):
# b'\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="fa" prefix="og: http://ogp.me/ns#">\r\n<head>\r\n    <title>\xd9\x85\xd8\xb1\xd8\xac\xd8\xb9 '

# %% [markdown]
# ## Parsing HTML with BeautifulSoup
# We'll start with a simple example to get familiar with BeautifulSoup's features:

# %%
# A simple HTML example",
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %% [markdown]
# ### Converting HTML text to a BeautifulSoup object

# %%
from bs4 import BeautifulSoup
# Create BeautifulSoup object from HTML text
soup = BeautifulSoup(html_doc, 'html.parser')

# Display HTML in a readable format",
print("🔍 Prettified HTML:")
print(soup.prettify())
# Out:
# 🔍 Prettified HTML:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Extracting and Manipulating HTML Elements\n",
# #### 1. Accessing Elements

# %%
# Title element",
print(f"🏷️ Title element: {soup.title} ")
print(f"📝 Element name: {soup.title.name}")
print(f"📄 Element text: {soup.title.string}")
print(f"👪 Parent element name: {soup.title.parent.name}")
# Out:
# 🏷️ Title element: <title>The Dormouse's story</title>
# 📝 Element name: title
# 📄 Element text: The Dormouse's story
# 👪 Parent element name: head

# %%
#First p element",
print(f"📌 First p element: {soup.p}")
print(f"🔖 p element class: {soup.p['class']}")
# Out:
# 📌 First p element: <p class="title"><b>The Dormouse's story</b></p>
# 🔖 p element class: ['title']

# %% [markdown]
# #### 2. Navigating Between Elements

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
# Access all links",
print(" 🔗 All links:")
for link in soup.find_all('a'):
    print(f"-{link.get('href')}")
#Extract all text",
print("📝 All text:")
print(soup.get_text())
# Out:
#  🔗 All links:
# -http://example.com/elsie
# -http://example.com/lacie
# -http://example.com/tillie
# 📝 All text:
#
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %% [markdown]
# #### 3. Working with Element Attributes

# %%
# Different ways to access element attributes",
print(f"🔖 p class using []: {soup.p['class']}")
print(f"🔖 p class using get(): {soup.p.get('class')}")
print(f"📦 All p attributes: {soup.p.attrs}")
# Out:
# 🔖 p class using []: ['title']
# 🔖 p class using get(): ['title']
# 📦 All p attributes: {'class': ['title']}

# %% [markdown]
# #### 4. Accessing Text Content

# %%
# Text inside p element",
print(f"📄 Text inside p element: {soup.p.string}")
# Text inside first link",
print(f"📄 Text inside first link: {soup.a.string}")
# Out:
# 📄 Text inside p element: The Dormouse's story
# 📄 Text inside first link: Elsie

# %% [markdown]
# #### 5. Navigating the HTML Tree

# %%
# Body contents",
print("👨‍👩‍👧‍👦 Body element contents:")
for i, item in enumerate(soup.body.contents):
    print(f"  {i}: {item}")
print(f"🔢 Number of elements inside body: {len(soup.body.contents)}")
# Out:
# 👨‍👩‍👧‍👦 Body element contents:
#   0:
#
#   1: <p class="title"><b>The Dormouse's story</b></p>
#   2:
#
#   3: <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
#   4:
#
#   5: <p class="story">...</p>
#   6:
#
# 🔢 Number of elements inside body: 7

# %% [markdown]
# ### Searching in HTML
# BeautifulSoup offers various methods for searching HTML:

# %%
# Recreate soup to be safe
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# Search by tag name"
print("🔍 Search for all b elements:")
print(soup.find_all('b'))
# Out:
# 🔍 Search for all b elements:
# [<b>The Dormouse's story</b>]

# %%
# Search using regular expression
import re
print("🔍 Search for all elements with names starting with 'b':")
for tag in soup.find_all(re.compile("^b")):
    print(f"  {tag}")

# Search for multiple element types",
print("🔍 Search for all a and b elements:")
print(soup.find_all(["a", "b"]))
# Out:
# 🔍 Search for all elements with names starting with 'b':
#   <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>
#   <b>The Dormouse's story</b>
# 🔍 Search for all a and b elements:
# [<b>The Dormouse's story</b>, <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# ### Advanced Search with Element Attributes

# %%
# Search by combining name and attributes
print("🔍 Search for all a elements with id='link1' and class='sister':")
result = soup.find_all(name="a", id="link1", class_="sister")
for item in result:
    print(f"  {item}")
# Search for the first matching element
print("🔍 Search for the first a element:")
print(soup.find("a"))
# Out:
# 🔍 Search for all a elements with id='link1' and class='sister':
#   <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# 🔍 Search for the first a element:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %% [markdown]
# ## 💻 Practical Example 1: Extracting News Text from a Sports Website

# %%
import requests
from bs4 import BeautifulSoup
# URL of a news article (replace with your chosen URL)"
url = "https://www.varzesh3.com/news/2113453/%D8%AF%D8%B1%D9%88%D8%A7%D8%B2%D9%87-%D8%A8%D8%A7%D9%86-%D8%AC%D8%AF%DB%8C%D8%AF-%D9%85%D9%84%DB%8C-%D9%BE%D9%88%D8%B4-%D8%A7%D8%B2-%D8%AA%DB%8C%D9%85-%D8%AD%D8%B3%DB%8C%D9%86%DB%8C-%D8%A7%D9%93%D9%85%D8%AF"
# Send GET request
response = requests.get(url)
# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")
# Find all paragraphs with the specific style attribute
paragraphs = soup.find_all("p", style="text-align:justify;")
# Extract and join the text of all paragraphs
news_text = "\n".join(p.text.strip() for p in paragraphs)
#Print the extracted news text
print("📰 Extracted News Content:")
print(news_text)
# Out:
# 📰 Extracted News Content:
# به گزارش "ورزش سه"، فهرست جدید تیم ملی فوتبال ایران در حالی از سوی امیر قلعه‌نویی اعلام شد که نام محمد خلیفه، دروازه‌بان ۲۰ ساله آلومینیوم اراک هم در آن دیده می‌شود.
# محمد خلیفه که در نقل و انتقالات تابستانی ۱۴۰۲ با نظر سیدمجتبی حسینی به آلومینیوم اراک پیوست و فرصت درخشش در لیگ برتر زیر نظر این سرمربی را به دست آورد، حالا در جمع ملی فوتبال ایران برای دو مسابقه مقدماتی جام جهانی ۲۰۲۶ مقابل امارات و ازبکستان قرار گرفته است.
# این دروازه‌بان در فصل گذشته لیگ برتر مقابل نساجی مازندران، استقلال تهران و فولاد خوزستان فرصت بازی به دست آورد و در فصل جاری هم غیر از یک مسابقه که به‌خاطر محرومیت حضور نداشت، در ۲۲ بازی دیگر همواره در ترکیب بوده و نمایش درخشانی ارائه داده است.
# خلیفه در ۲۲ مسابقه فصل جاری لیگ برتر توانسته ۸ کلین‌شیت به ثبت رساند و امشب هم علی‌رغم دریافت دو گل مقابل فولاد خوزستان نمایش خوبی داشت تا برای نخستین بار شانس دعوت شدن به تیم ملی را به دست بیاورد.
# در فصل جاری جوانان پرشماری با نظر مجتبی حسینی فرصت خودنمایی در‌ آلومینیوم اراک را به‌دست آوردند و محمد خلیفه در دومین فصل حضورش در لیگ برتر توانسته به اردوی تیم ملی دعوت شود و حالا باید با گلرهایی مثل علیرضا بیرانوند، سید پیام نیازمند و … رقابت و در کنارشان کسب تجربه کند.

# %% [markdown]
# # 🤖 Part 2: Web Automation with Selenium
# For dynamic websites where content is loaded using JavaScript, we need Selenium.

# %% [markdown]
# ## Installing Selenium and Setting Up the WebDriver

# %%
# Install Selenium if not already installed"
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\amirreza\anaconda3\lib\site-packages (4.29.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\amirreza\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (2023.11.17)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\amirreza\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\amirreza\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\amirreza\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\amirreza\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\amirreza\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\amirreza\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# You may need to download the appropriate ChromeDriver from:
# https://sites.google.com/chromium.org/driver/

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time

# Initialize the Chrome driver
driver = webdriver.Chrome()

# %%
# Open Google's homepage
driver.get("http://www.google.com")

# %%
# Close the browser window
driver.close()

# %%
# Reopen browser and navigate to Google
driver = webdriver.Chrome()
driver.get("http://www.google.com")

# %%
# Find the search box element by its ID
element = driver.find_element(By.ID, "APjFqb")

# Alternative ways to find elements:
# element = driver.find_element(By.NAME, "textarea")
# element = driver.find_element(By.XPATH, "//input[@id='passwd-id']")
# element = driver.find_element(By.CSS_SELECTOR, "input#passwd-id")

# %%
# Type "NLP" into the search box
element.send_keys("NLP")

# %%
# Find the search button by its class name and click it
element = driver.find_element(By.CLASS_NAME, "gNO89b")
element.click()

# %%
# Navigate to a Google Form
driver.get('https://docs.google.com/forms/d/e/1FAIpQLSe0sa36n5-td7G-r0WP2ggHLStW__xOZKFQYypZs04GN3fvgA/viewform?usp=headerg')

# %%
# Find radio button options and click each one with a delay
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[2]")

all_options = element.find_elements(By.TAG_NAME, "label")
for option in all_options:
    option.click()
    time.sleep(2)

# %%
# Find a text input field by its XPATH
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[2]/div[1]/div/div/div[2]/div/div[1]/div/div[1]/input")

# %%
# Type a name into the input field
element.send_keys("Amirreza")

# %%
# List of all Selenium locator strategies
# ID = "id"
# NAME = "name"
# XPATH = "xpath"
# LINK_TEXT = "link text"
# PARTIAL_LINK_TEXT = "partial link text"
# TAG_NAME = "tag name"
# CLASS_NAME = "class name"
# CSS_SELECTOR = "css selector"

# %%
# Close the browser window
driver.close()

# %% [markdown]
# # API

# %%
# API Requests

import requests

# GET request example
api_url = "https://jsonplaceholder.typicode.com/todos/1"
response = requests.get(api_url)
response.json()
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %%
# POST request example
import requests

api_url = "https://jsonplaceholder.typicode.com/todos"
todo = {"userId": 1, "title": "Buy milk", "completed": False}
response = requests.post(api_url, json=todo)
response.json()
# Out:
# {'userId': 1, 'title': 'Buy milk', 'completed': False, 'id': 201}

# %% [markdown]
# # Example2
# Complete the following form using the concepts learned in class.

# %%
# Example 2: Complete a Google Form using Selenium

driver = webdriver.Chrome()
driver.get("https://docs.google.com/forms/d/e/1FAIpQLSe0sa36n5-td7G-r0WP2ggHLStW__xOZKFQYypZs04GN3fvgA/viewform?usp=headerg")

# %%
# Enter first name
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[2]/div[1]/div/div/div[2]/div/div[1]/div/div[1]/input")
element.send_keys("Amirreza")

# Enter Student number
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[2]/div[2]/div/div/div[2]/div/div[1]/div/div[1]/input")
element.send_keys("123456789")

# Enter email address
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[2]/div[3]/div/div/div[2]/div/div[1]/div/div[1]/input")
element.send_keys("amirrezahosseinymehr@gmail.com")

# Select radio button
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[2]/div[4]/div/div/div[2]/div/div/span/div/div[1]/label")
element.click()

# Enter text in textarea
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[2]/div[5]/div/div/div[2]/div/div[1]/div[2]/textarea")
element.send_keys(news_text)

# %%
# Click submit button
element = driver.find_element(By.XPATH, "/html/body/div/div[2]/form/div[2]/div/div[3]/div[1]/div[1]/div/span")
element.click()

# %% [markdown]
# # More Example

# %%
from tqdm import tqdm
import requests
from bs4 import BeautifulSoup
import os

if not os.path.exists('download_log.txt'):
    with open('download_log.txt', 'w') as f:
        pass
with open('download_log.txt', 'r+') as f:
    lecture_names = f.readlines()
lecture_names = [i.strip() for i in lecture_names]

base_url = 'https://{user}:{pass}@language.ml/courses/nlp14032/'

user = "sharif1400"
pass_ = "sharif1400"

page = requests.get(f'https://{user}:{pass_}@language.ml/courses/nlp14032/index.html')

soup = BeautifulSoup(page.content, 'html.parser')

table = soup.find('tbody')
trs = table.find_all('tr')

for i in tqdm(trs):
    tds = i.find_all('td')
    print(tds[0].string)
    print('-'*10)
    
    if tds[0].string in lecture_names and tds[0].string!=None:
        continue
        
    lecture_names.append(tds[0].string)
    if tds[2].a!=None:
        print(base_url+tds[2].a.get('href'))
        r = requests.get(base_url+tds[2].a.get('href'), auth=(user, pass_))
        with open(tds[0].string+'.pdf', 'wb') as f:
            f.write(r.content)
    if tds[3].a!=None:
        print(base_url+tds[3].a.get('href'))
        r = requests.get(base_url+tds[3].a.get('href'), auth=(user, pass_))
        with open(tds[0].string+'.mp4', 'wb') as f:
            f.write(r.content)
        

lecture_names = [i for i in lecture_names if i!=None]
with open('download_log.txt', 'w') as f:
    f.write('\n'.join(lecture_names))
# Out:
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
# W1-1
# ----------
# https://{user}:{pass}@language.ml/courses/nlp14032/slides/slide-1.pdf
# https://{user}:{pass}@language.ml/courses/nlp14032/videos/01.mp4
#   0%|                                                                                            | 0/7 [00:15<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 41
#      39 if tds[3].a!=None:
#      40     print(base_url+tds[3].a.get('href'))
# ---> 41     r = requests.get(base_url+tds[3].a.get('href'), auth=(user, pass_))
#      42     with open(tds[0].string+'.mp4', 'wb') as f:
#      43         f.write(r.content)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\anaconda3\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
## Install Scrapy
# !pip install scrapy
## Check installation
import scrapy
print(scrapy.__version__)
# Out:
# Requirement already satisfied: scrapy in c:\users\amirreza\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: Twisted>=18.9.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (38.0.4)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (22.1.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (1.21.0)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: protego>=0.1.15 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: setuptools in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (58.0.4)
# Requirement already satisfied: packaging in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (23.1)
# Requirement already satisfied: tldextract in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (3.2.0)
# Requirement already satisfied: lxml>=4.3.0 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\amirreza\anaconda3\lib\site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\amirreza\anaconda3\lib\site-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\amirreza\anaconda3\lib\site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: six>=1.6.0 in c:\users\amirreza\anaconda3\lib\site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=16.0.0 in c:\users\amirreza\anaconda3\lib\site-packages (from service-identity>=18.1.0->scrapy) (25.1.0)
# Requirement already satisfied: pyasn1-modules in c:\users\amirreza\anaconda3\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: pyasn1 in c:\users\amirreza\anaconda3\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: constantly>=15.1 in c:\users\amirreza\anaconda3\lib\site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\amirreza\anaconda3\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.3.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\amirreza\anaconda3\lib\site-packages (from Twisted>=18.9.0->scrapy) (20.2.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\amirreza\anaconda3\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\amirreza\anaconda3\lib\site-packages (from Twisted>=18.9.0->scrapy) (4.12.2)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\amirreza\anaconda3\lib\site-packages (from Twisted>=18.9.0->scrapy) (1.0.2)
# Requirement already satisfied: idna in c:\users\amirreza\anaconda3\lib\site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in c:\users\amirreza\anaconda3\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\amirreza\anaconda3\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\amirreza\anaconda3\lib\site-packages (from tldextract->scrapy) (3.9.0)
# Requirement already satisfied: pycparser in c:\users\amirreza\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amirreza\anaconda3\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amirreza\anaconda3\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amirreza\anaconda3\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.11.17)
# 2.8.0

# %%
## Running the spider in Jupyter environment
from scrapy.crawler import CrawlerProcess
class Varzesh3Spider(scrapy.Spider):
    name = "varzesh3"
    start_urls = [
        'https://www.varzesh3.com/'
    ]
    def parse(self, response):
        matches = []
        for match in response.css('div.fixture-result-match'):
            matches.append({
                'date': match.xpath('preceding::div[@class="date-seprator"]/h4/text()').get(),
                'home_team': match.css('div.fixture-result-match-host span::text').get(),
                'away_team': match.css('div.fixture-result-match-guest span::text').get(),
                'score': match.css('div.fixture-result-match-goals::text').get(),
                'match_link': response.urljoin(match.css('a.fixture-result-match-teams::attr(href)').get()),
                'video_link': match.css('div.fixture-result-match-time a::attr(href)').get()
            })
        return matches
## Running the spider in Jupyter Notebook
process = CrawlerProcess({
    'FEEDS': {
        'matches.json': {'format': 'json'},
    },
})
process.crawl(Varzesh3Spider)
process.start()
# Out:
# 2025-03-15 17:19:34 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2025-03-15 17:19:34 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.4, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.10.0, Python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.1.0 (OpenSSL 3.0.7 1 Nov 2022), cryptography 38.0.4, Platform Windows-10-10.0.19045-SP0
# 2025-03-15 17:19:34 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2025-03-15 17:19:34 [py.warnings] WARNING: C:\Users\Amirreza\anaconda3\Lib\site-packages\scrapy\utils\request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2025-03-15 17:19:34 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-03-15 17:19:34 [scrapy.extensions.telnet] INFO: Telnet Password: d04723a56206a094
# 2025-03-15 17:19:34 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-03-15 17:19:34 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-03-15 17:19:34 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-03-15 17:19:34 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-03-15 17:19:34 [scrapy.core.engine] INFO: Spider opened
# 2025-03-15 17:19:34 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-03-15 17:19:34 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-03-15 17:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.varzesh3.com/> (referer: None)
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'هوادار', 'away_team': 'شمس آذر قزوین', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415944/بازی-هوادار-شمس-آذر-قزوین', 'video_link': 'https://video.varzesh3.com/video/370703/خلاصه-بازی-هوادار-2-شمس-آذر-قزوین-3'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'نساجی مازندران', 'away_team': 'سپاهان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415948/بازی-نساجی-مازندران-سپاهان', 'video_link': 'https://video.varzesh3.com/video/370702/خلاصه-بازی-نساجی-مازندران-1-سپاهان-1'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'خیبر خرم آباد', 'away_team': 'چادرملو اردکان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415943/بازی-خیبر-خرم-آباد-چادرملو-اردکان', 'video_link': 'https://video.varzesh3.com/video/370704/خلاصه-بازی-خیبر-خرم-آباد-2-چادرملو-اردکان-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'مس رفسنجان', 'away_team': 'استقلال خوزستان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415945/بازی-مس-رفسنجان-استقلال-خوزستان', 'video_link': 'https://video.varzesh3.com/video/370783/خلاصه-بازی-مس-رفسنجان-0-استقلال-خوزستان-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'پرسپولیس', 'away_team': 'ملوان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415950/بازی-پرسپولیس-ملوان', 'video_link': 'https://video.varzesh3.com/video/370784/خلاصه-بازی-پرسپولیس-2-ملوان-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'فولاد', 'away_team': 'آلومینیوم اراک', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415947/بازی-فولاد-آلومینیوم-اراک', 'video_link': 'https://video.varzesh3.com/video/370786/خلاصه-بازی-فولاد-خوزستان-2-آلومینیوم-اراک-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ذوب آهن', 'away_team': 'استقلال', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415946/بازی-ذوب-آهن-استقلال', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'تراکتور', 'away_team': 'گل گهرسیرجان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/415949/بازی-تراکتور-گل-گهرسیرجان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109516/بازی-طبیعت-پایش-پارت-شاهرود', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109518/بازی-پالایش-نفت-آبادان-مهگل-البرز', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109517/بازی-کاله-ذوب-آهن', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109531/بازی-طبیعت-پایش-پارت-شاهرود', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109519/بازی-شهرداری-گرگان-گلنور-اصفهان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109532/بازی-پالایش-نفت-آبادان-مهگل-البرز', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109533/بازی-کاله-ذوب-آهن', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109534/بازی-شهرداری-گرگان-گلنور-اصفهان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109535/بازی-ذوب-آهن-کاله', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109536/بازی-مهگل-البرز-پالایش-نفت-آبادان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109537/بازی-گلنور-اصفهان-شهرداری-گرگان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': None, 'away_team': None, 'score': None, 'match_link': 'https://www.varzesh3.com/basketball/match/109538/بازی-مهگل-البرز-پالایش-نفت-آبادان', 'video_link': 'https://video.varzesh3.com/video/370341/خلاصه-بسکتبال-مهگل-البرز-پالایش-نفت-آبادان'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'مس کرمان', 'away_team': 'زغال سنگ طبس', 'score': None, 'match_link': 'https://www.varzesh3.com/handball/match/460/بازی-مس-کرمان-زغال-سنگ-طبس', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'نیروی زمینی کازرون', 'away_team': 'سنگ آهن بافق', 'score': None, 'match_link': 'https://www.varzesh3.com/handball/match/458/بازی-نیروی-زمینی-کازرون-سنگ-آهن-بافق', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'سپاهان', 'away_team': 'سپاهان نوین', 'score': None, 'match_link': 'https://www.varzesh3.com/handball/match/459/بازی-سپاهان-سپاهان-نوین', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'گیتی پسند', 'away_team': 'آلومینیوم اراک', 'score': None, 'match_link': 'https://www.varzesh3.com/handball/match/461/بازی-گیتی-پسند-آلومینیوم-اراک', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'شهید چمران لارستان', 'away_team': 'نفت و گاز گچساران', 'score': None, 'match_link': 'https://www.varzesh3.com/handball/match/462/بازی-شهید-چمران-لارستان-نفت-و-گاز-گچساران', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'استقلال', 'away_team': 'النصر', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417666/بازی-استقلال-النصر', 'video_link': 'https://video.varzesh3.com/video/369881/خلاصه-بازی-استقلال-ایران-0-النصر-عربستان-0-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'الوصل امارات', 'away_team': 'السد', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417667/بازی-الوصل-امارات-السد', 'video_link': 'https://video.varzesh3.com/video/369901/خلاصه-بازی-الوصل-امارات-1-السد-1-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'شانگهای پورت', 'away_team': 'یوکوهاما مارینوس', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417875/بازی-شانگهای-پورت-یوکوهاما-مارینوس', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'بوریرام تایلند', 'away_team': 'جوهور دارالتعظیم', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417876/بازی-بوریرام-تایلند-جوهور-دارالتعظیم', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'پاختاکور', 'away_team': 'الهلال', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417664/بازی-پاختاکور-الهلال', 'video_link': 'https://video.varzesh3.com/video/369996/خلاصه-بازی-پاختاکور-1-الهلال-0-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'الریان', 'away_team': 'الاهلی عربستان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417665/بازی-الریان-الاهلی-عربستان', 'video_link': 'https://video.varzesh3.com/video/370019/خلاصه-بازی-الریان-1-الاهلی-عربستان-3'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ویسل کوبه', 'away_team': 'گوانگژو اف سی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417877/بازی-ویسل-کوبه-گوانگژو-اف-سی', 'video_link': 'https://video.varzesh3.com/video/370119/خلاصه-بازی-ویسل-کوبه-2-گوانگژو-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'شانگهای شنهوا', 'away_team': 'کاوازاکی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417878/بازی-شانگهای-شنهوا-کاوازاکی', 'video_link': 'https://video.varzesh3.com/video/370118/خلاصه-بازی-شانگهای-شنهوا-1-کاوازاکی-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'النصر', 'away_team': 'استقلال', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417670/بازی-النصر-استقلال', 'video_link': 'https://video.varzesh3.com/video/370483/خلاصه-بازی-النصر-عربستان-3-استقلال-ایران-0-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'السد', 'away_team': 'الوصل امارات', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417671/بازی-السد-الوصل-امارات', 'video_link': 'https://video.varzesh3.com/video/370485/خلاصه-بازی-السد-قطر-3-الوصل-امارات-1-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'یوکوهاما مارینوس', 'away_team': 'شانگهای پورت', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417879/بازی-یوکوهاما-مارینوس-شانگهای-پورت', 'video_link': 'https://video.varzesh3.com/video/370543/خلاصه-بازی-یوکوهاما-مارینوس-4-شانگهای-پورت-1'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'جوهور دارالتعظیم', 'away_team': 'بوریرام تایلند', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417880/بازی-جوهور-دارالتعظیم-بوریرام-تایلند', 'video_link': 'https://video.varzesh3.com/video/370553/خلاصه-بازی-جوهور-دارالتعظیم-0-بوریرام-تایلند-1'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'الهلال', 'away_team': 'پاختاکور', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417668/بازی-الهلال-پاختاکور', 'video_link': 'https://video.varzesh3.com/video/370623/خلاصه-بازی-الهلال-4-پاختاکور-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'الاهلی عربستان', 'away_team': 'الریان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417669/بازی-الاهلی-عربستان-الریان', 'video_link': 'https://video.varzesh3.com/video/370624/خلاصه-بازی-الاهلی-2-الریان-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'گوانگژو اف سی', 'away_team': 'ویسل کوبه', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417881/بازی-گوانگژو-اف-سی-ویسل-کوبه', 'video_link': 'https://video.varzesh3.com/video/370767/خلاصه-بازی-گوانگژو-اف-سی-3-ویسل-کوبه-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'کاوازاکی', 'away_team': 'شانگهای شنهوا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417882/بازی-کاوازاکی-شانگهای-شنهوا', 'video_link': 'https://video.varzesh3.com/video/370766/خلاصه-بازی-کاوازاکی-4-شانگهای-شنهوا-0'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'التعاون', 'away_team': 'شارجه امارات', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418000/بازی-التعاون-شارجه-امارات', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'لاین سیتی سیلرز', 'away_team': 'سیدنی اف سی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418007/بازی-لاین-سیتی-سیلرز-سیدنی-اف-سی', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'شارجه امارات', 'away_team': 'التعاون', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418001/بازی-شارجه-امارات-التعاون', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'سیدنی اف سی', 'away_team': 'لاین سیتی سیلرز', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418008/بازی-سیدنی-اف-سی-لاین-سیتی-سیلرز', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'بایرن مونیخ', 'away_team': 'اینتر', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417993/بازی-بایرن-مونیخ-اینتر', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'آرسنال', 'away_team': 'رئال مادرید', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418005/بازی-آرسنال-رئال-مادرید', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'بارسلونا', 'away_team': 'دورتموند', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417998/بازی-بارسلونا-دورتموند', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'پاری سن ژرمن', 'away_team': 'استون ویلا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418003/بازی-پاری-سن-ژرمن-استون-ویلا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'دورتموند', 'away_team': 'بارسلونا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417999/بازی-دورتموند-بارسلونا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'استون ویلا', 'away_team': 'پاری سن ژرمن', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418004/بازی-استون-ویلا-پاری-سن-ژرمن', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اینتر', 'away_team': 'بایرن مونیخ', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417994/بازی-اینتر-بایرن-مونیخ', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'رئال مادرید', 'away_team': 'آرسنال', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418006/بازی-رئال-مادرید-آرسنال', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'بوده', 'away_team': 'لاتزیو', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418009/بازی-بوده-لاتزیو', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'تاتنهام', 'away_team': 'آینتراخت فرانکفورت', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418017/بازی-تاتنهام-آینتراخت-فرانکفورت', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'لیون', 'away_team': 'منچستر یونایتد', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418019/بازی-لیون-منچستر-یونایتد', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'گلاسکو رنجرز', 'away_team': 'اتلتیک بیلبائو', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418023/بازی-گلاسکو-رنجرز-اتلتیک-بیلبائو', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'لاتزیو', 'away_team': 'بوده', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418010/بازی-لاتزیو-بوده', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'آینتراخت فرانکفورت', 'away_team': 'تاتنهام', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418018/بازی-آینتراخت-فرانکفورت-تاتنهام', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'منچستر یونایتد', 'away_team': 'لیون', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418020/بازی-منچستر-یونایتد-لیون', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اتلتیک بیلبائو', 'away_team': 'گلاسکو رنجرز', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418024/بازی-اتلتیک-بیلبائو-گلاسکو-رنجرز', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'لژیا', 'away_team': 'چلسی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418021/بازی-لژیا-چلسی', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'دورگاردن', 'away_team': 'راپید وین', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418011/بازی-دورگاردن-راپید-وین', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'رئال بتیس', 'away_team': 'جاگیلونیا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418013/بازی-رئال-بتیس-جاگیلونیا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'سلیه', 'away_team': 'فیورنتینا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418015/بازی-سلیه-فیورنتینا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'جاگیلونیا', 'away_team': 'رئال بتیس', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418014/بازی-جاگیلونیا-رئال-بتیس', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'فیورنتینا', 'away_team': 'سلیه', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418016/بازی-فیورنتینا-سلیه', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'راپید وین', 'away_team': 'دورگاردن', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418012/بازی-راپید-وین-دورگاردن', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'چلسی', 'away_team': 'لژیا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/418022/بازی-چلسی-لژیا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'هلند', 'away_team': 'اسپانیا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414968/بازی-هلند-اسپانیا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'کرواسی', 'away_team': 'فرانسه', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414969/بازی-کرواسی-فرانسه', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'دانمارک', 'away_team': 'پرتغال', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414970/بازی-دانمارک-پرتغال', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ایتالیا', 'away_team': 'آلمان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414971/بازی-ایتالیا-آلمان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اسپانیا', 'away_team': 'هلند', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414972/بازی-اسپانیا-هلند', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'فرانسه', 'away_team': 'کرواسی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414973/بازی-فرانسه-کرواسی', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'پرتغال', 'away_team': 'دانمارک', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414974/بازی-پرتغال-دانمارک', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'آلمان', 'away_team': 'ایتالیا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/414975/بازی-آلمان-ایتالیا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'استون ویلا', 'away_team': 'لیورپول', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402823/بازی-استون-ویلا-لیورپول', 'video_link': 'https://video.varzesh3.com/video/368775/خلاصه-بازی-استون-ویلا-2-لیورپول-2-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اورتون', 'away_team': 'وستهم', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402825/بازی-اورتون-وستهم', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ایپسویچ', 'away_team': 'ناتینگهام فارست', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402827/بازی-ایپسویچ-ناتینگهام-فارست', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'منچسترسیتی', 'away_team': 'برایتون', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402829/بازی-منچسترسیتی-برایتون', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ساوتهمپتون', 'away_team': 'ولورهمپتون', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402831/بازی-ساوتهمپتون-ولورهمپتون', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'بورنموث', 'away_team': 'برنتفورد', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402824/بازی-بورنموث-برنتفورد', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'آرسنال', 'away_team': 'چلسی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402822/بازی-آرسنال-چلسی', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'فولام', 'away_team': 'تاتنهام', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402826/بازی-فولام-تاتنهام', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'لسترسیتی', 'away_team': 'منچستر یونایتد', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402828/بازی-لسترسیتی-منچستر-یونایتد', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'نیوکسل', 'away_team': 'کریستال پالاس', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/402830/بازی-نیوکسل-کریستال-پالاس', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'نساجی مازندران', 'away_team': 'گل گهرسیرجان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417842/بازی-نساجی-مازندران-گل-گهرسیرجان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ملوان', 'away_team': 'سپاهان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417841/بازی-ملوان-سپاهان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'صنعت نفت آبادان', 'away_team': 'شهرداری نوشهر', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417840/بازی-صنعت-نفت-آبادان-شهرداری-نوشهر', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'استقلال', 'away_team': 'پیکان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/417843/بازی-استقلال-پیکان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اسپانیا', 'away_team': 'انگلیس', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/410074/بازی-اسپانیا-انگلیس', 'video_link': 'https://video.varzesh3.com/video/347555/خلاصه-بازی-اسپانیا-2-انگلیس-1-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اردن', 'away_team': 'قطر', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/399893/بازی-اردن-قطر', 'video_link': 'https://video.varzesh3.com/video/324357/خلاصه-بازی-اردن-1-قطر-3'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'آرژانتین', 'away_team': 'کلمبیا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/410123/بازی-آرژانتین-کلمبیا', 'video_link': 'https://video.varzesh3.com/video/347571/خلاصه-بازی-آرژانتین-1-کلمبیا-0-گزارش-اختصاصی'}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ایران', 'away_team': 'امارات', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/405970/بازی-ایران-امارات', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'ازبکستان', 'away_team': 'قرقیزستان', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/405987/بازی-ازبکستان-قرقیزستان', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'قطر', 'away_team': 'کره شمالی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/405986/بازی-قطر-کره-شمالی', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'پاراگوئه', 'away_team': 'شیلی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/398291/بازی-پاراگوئه-شیلی', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'برزیل', 'away_team': 'کلمبیا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/398289/بازی-برزیل-کلمبیا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'پرو', 'away_team': 'بولیوی', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/398292/بازی-پرو-بولیوی', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اکوادور', 'away_team': 'ونزوئلا', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/398290/بازی-اکوادور-ونزوئلا', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.varzesh3.com/>
# {'date': 'پنج شنبه 23 اسفند', 'home_team': 'اروگوئه', 'away_team': 'آرژانتین', 'score': None, 'match_link': 'https://www.varzesh3.com/football/match/398293/بازی-اروگوئه-آرژانتین', 'video_link': None}
# 2025-03-15 17:19:40 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-03-15 17:19:40 [scrapy.extensions.feedexport] INFO: Stored json feed (102 items) in: matches.json
# 2025-03-15 17:19:40 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 226,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 98700,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 6.065086,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 3, 15, 13, 49, 40, 794561),
#  'httpcompression/response_bytes': 788493,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 102,
#  'log_count/DEBUG': 104,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 3, 15, 13, 49, 34, 729475)}
# 2025-03-15 17:19:40 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
## Display JSON output
import json
with open('matches.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
    print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "هوادار",
#         "away_team": "شمس آذر قزوین",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415944/بازی-هوادار-شمس-آذر-قزوین",
#         "video_link": "https://video.varzesh3.com/video/370703/خلاصه-بازی-هوادار-2-شمس-آذر-قزوین-3"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "نساجی مازندران",
#         "away_team": "سپاهان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415948/بازی-نساجی-مازندران-سپاهان",
#         "video_link": "https://video.varzesh3.com/video/370702/خلاصه-بازی-نساجی-مازندران-1-سپاهان-1"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "خیبر خرم آباد",
#         "away_team": "چادرملو اردکان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415943/بازی-خیبر-خرم-آباد-چادرملو-اردکان",
#         "video_link": "https://video.varzesh3.com/video/370704/خلاصه-بازی-خیبر-خرم-آباد-2-چادرملو-اردکان-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "مس رفسنجان",
#         "away_team": "استقلال خوزستان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415945/بازی-مس-رفسنجان-استقلال-خوزستان",
#         "video_link": "https://video.varzesh3.com/video/370783/خلاصه-بازی-مس-رفسنجان-0-استقلال-خوزستان-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "پرسپولیس",
#         "away_team": "ملوان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415950/بازی-پرسپولیس-ملوان",
#         "video_link": "https://video.varzesh3.com/video/370784/خلاصه-بازی-پرسپولیس-2-ملوان-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "فولاد",
#         "away_team": "آلومینیوم اراک",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415947/بازی-فولاد-آلومینیوم-اراک",
#         "video_link": "https://video.varzesh3.com/video/370786/خلاصه-بازی-فولاد-خوزستان-2-آلومینیوم-اراک-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ذوب آهن",
#         "away_team": "استقلال",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415946/بازی-ذوب-آهن-استقلال",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "تراکتور",
#         "away_team": "گل گهرسیرجان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/415949/بازی-تراکتور-گل-گهرسیرجان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109516/بازی-طبیعت-پایش-پارت-شاهرود",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109518/بازی-پالایش-نفت-آبادان-مهگل-البرز",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109517/بازی-کاله-ذوب-آهن",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109531/بازی-طبیعت-پایش-پارت-شاهرود",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109519/بازی-شهرداری-گرگان-گلنور-اصفهان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109532/بازی-پالایش-نفت-آبادان-مهگل-البرز",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109533/بازی-کاله-ذوب-آهن",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109534/بازی-شهرداری-گرگان-گلنور-اصفهان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109535/بازی-ذوب-آهن-کاله",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109536/بازی-مهگل-البرز-پالایش-نفت-آبادان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109537/بازی-گلنور-اصفهان-شهرداری-گرگان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": null,
#         "away_team": null,
#         "score": null,
#         "match_link": "https://www.varzesh3.com/basketball/match/109538/بازی-مهگل-البرز-پالایش-نفت-آبادان",
#         "video_link": "https://video.varzesh3.com/video/370341/خلاصه-بسکتبال-مهگل-البرز-پالایش-نفت-آبادان"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "مس کرمان",
#         "away_team": "زغال سنگ طبس",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/handball/match/460/بازی-مس-کرمان-زغال-سنگ-طبس",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "نیروی زمینی کازرون",
#         "away_team": "سنگ آهن بافق",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/handball/match/458/بازی-نیروی-زمینی-کازرون-سنگ-آهن-بافق",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "سپاهان",
#         "away_team": "سپاهان نوین",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/handball/match/459/بازی-سپاهان-سپاهان-نوین",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "گیتی پسند",
#         "away_team": "آلومینیوم اراک",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/handball/match/461/بازی-گیتی-پسند-آلومینیوم-اراک",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "شهید چمران لارستان",
#         "away_team": "نفت و گاز گچساران",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/handball/match/462/بازی-شهید-چمران-لارستان-نفت-و-گاز-گچساران",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "استقلال",
#         "away_team": "النصر",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417666/بازی-استقلال-النصر",
#         "video_link": "https://video.varzesh3.com/video/369881/خلاصه-بازی-استقلال-ایران-0-النصر-عربستان-0-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "الوصل امارات",
#         "away_team": "السد",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417667/بازی-الوصل-امارات-السد",
#         "video_link": "https://video.varzesh3.com/video/369901/خلاصه-بازی-الوصل-امارات-1-السد-1-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "شانگهای پورت",
#         "away_team": "یوکوهاما مارینوس",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417875/بازی-شانگهای-پورت-یوکوهاما-مارینوس",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "بوریرام تایلند",
#         "away_team": "جوهور دارالتعظیم",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417876/بازی-بوریرام-تایلند-جوهور-دارالتعظیم",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "پاختاکور",
#         "away_team": "الهلال",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417664/بازی-پاختاکور-الهلال",
#         "video_link": "https://video.varzesh3.com/video/369996/خلاصه-بازی-پاختاکور-1-الهلال-0-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "الریان",
#         "away_team": "الاهلی عربستان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417665/بازی-الریان-الاهلی-عربستان",
#         "video_link": "https://video.varzesh3.com/video/370019/خلاصه-بازی-الریان-1-الاهلی-عربستان-3"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ویسل کوبه",
#         "away_team": "گوانگژو اف سی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417877/بازی-ویسل-کوبه-گوانگژو-اف-سی",
#         "video_link": "https://video.varzesh3.com/video/370119/خلاصه-بازی-ویسل-کوبه-2-گوانگژو-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "شانگهای شنهوا",
#         "away_team": "کاوازاکی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417878/بازی-شانگهای-شنهوا-کاوازاکی",
#         "video_link": "https://video.varzesh3.com/video/370118/خلاصه-بازی-شانگهای-شنهوا-1-کاوازاکی-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "النصر",
#         "away_team": "استقلال",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417670/بازی-النصر-استقلال",
#         "video_link": "https://video.varzesh3.com/video/370483/خلاصه-بازی-النصر-عربستان-3-استقلال-ایران-0-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "السد",
#         "away_team": "الوصل امارات",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417671/بازی-السد-الوصل-امارات",
#         "video_link": "https://video.varzesh3.com/video/370485/خلاصه-بازی-السد-قطر-3-الوصل-امارات-1-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "یوکوهاما مارینوس",
#         "away_team": "شانگهای پورت",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417879/بازی-یوکوهاما-مارینوس-شانگهای-پورت",
#         "video_link": "https://video.varzesh3.com/video/370543/خلاصه-بازی-یوکوهاما-مارینوس-4-شانگهای-پورت-1"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "جوهور دارالتعظیم",
#         "away_team": "بوریرام تایلند",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417880/بازی-جوهور-دارالتعظیم-بوریرام-تایلند",
#         "video_link": "https://video.varzesh3.com/video/370553/خلاصه-بازی-جوهور-دارالتعظیم-0-بوریرام-تایلند-1"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "الهلال",
#         "away_team": "پاختاکور",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417668/بازی-الهلال-پاختاکور",
#         "video_link": "https://video.varzesh3.com/video/370623/خلاصه-بازی-الهلال-4-پاختاکور-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "الاهلی عربستان",
#         "away_team": "الریان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417669/بازی-الاهلی-عربستان-الریان",
#         "video_link": "https://video.varzesh3.com/video/370624/خلاصه-بازی-الاهلی-2-الریان-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "گوانگژو اف سی",
#         "away_team": "ویسل کوبه",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417881/بازی-گوانگژو-اف-سی-ویسل-کوبه",
#         "video_link": "https://video.varzesh3.com/video/370767/خلاصه-بازی-گوانگژو-اف-سی-3-ویسل-کوبه-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "کاوازاکی",
#         "away_team": "شانگهای شنهوا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417882/بازی-کاوازاکی-شانگهای-شنهوا",
#         "video_link": "https://video.varzesh3.com/video/370766/خلاصه-بازی-کاوازاکی-4-شانگهای-شنهوا-0"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "التعاون",
#         "away_team": "شارجه امارات",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418000/بازی-التعاون-شارجه-امارات",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "لاین سیتی سیلرز",
#         "away_team": "سیدنی اف سی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418007/بازی-لاین-سیتی-سیلرز-سیدنی-اف-سی",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "شارجه امارات",
#         "away_team": "التعاون",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418001/بازی-شارجه-امارات-التعاون",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "سیدنی اف سی",
#         "away_team": "لاین سیتی سیلرز",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418008/بازی-سیدنی-اف-سی-لاین-سیتی-سیلرز",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "بایرن مونیخ",
#         "away_team": "اینتر",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417993/بازی-بایرن-مونیخ-اینتر",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "آرسنال",
#         "away_team": "رئال مادرید",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418005/بازی-آرسنال-رئال-مادرید",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "بارسلونا",
#         "away_team": "دورتموند",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417998/بازی-بارسلونا-دورتموند",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "پاری سن ژرمن",
#         "away_team": "استون ویلا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418003/بازی-پاری-سن-ژرمن-استون-ویلا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "دورتموند",
#         "away_team": "بارسلونا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417999/بازی-دورتموند-بارسلونا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "استون ویلا",
#         "away_team": "پاری سن ژرمن",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418004/بازی-استون-ویلا-پاری-سن-ژرمن",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اینتر",
#         "away_team": "بایرن مونیخ",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417994/بازی-اینتر-بایرن-مونیخ",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "رئال مادرید",
#         "away_team": "آرسنال",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418006/بازی-رئال-مادرید-آرسنال",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "بوده",
#         "away_team": "لاتزیو",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418009/بازی-بوده-لاتزیو",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "تاتنهام",
#         "away_team": "آینتراخت فرانکفورت",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418017/بازی-تاتنهام-آینتراخت-فرانکفورت",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "لیون",
#         "away_team": "منچستر یونایتد",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418019/بازی-لیون-منچستر-یونایتد",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "گلاسکو رنجرز",
#         "away_team": "اتلتیک بیلبائو",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418023/بازی-گلاسکو-رنجرز-اتلتیک-بیلبائو",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "لاتزیو",
#         "away_team": "بوده",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418010/بازی-لاتزیو-بوده",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "آینتراخت فرانکفورت",
#         "away_team": "تاتنهام",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418018/بازی-آینتراخت-فرانکفورت-تاتنهام",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "منچستر یونایتد",
#         "away_team": "لیون",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418020/بازی-منچستر-یونایتد-لیون",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اتلتیک بیلبائو",
#         "away_team": "گلاسکو رنجرز",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418024/بازی-اتلتیک-بیلبائو-گلاسکو-رنجرز",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "لژیا",
#         "away_team": "چلسی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418021/بازی-لژیا-چلسی",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "دورگاردن",
#         "away_team": "راپید وین",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418011/بازی-دورگاردن-راپید-وین",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "رئال بتیس",
#         "away_team": "جاگیلونیا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418013/بازی-رئال-بتیس-جاگیلونیا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "سلیه",
#         "away_team": "فیورنتینا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418015/بازی-سلیه-فیورنتینا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "جاگیلونیا",
#         "away_team": "رئال بتیس",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418014/بازی-جاگیلونیا-رئال-بتیس",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "فیورنتینا",
#         "away_team": "سلیه",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418016/بازی-فیورنتینا-سلیه",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "راپید وین",
#         "away_team": "دورگاردن",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418012/بازی-راپید-وین-دورگاردن",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "چلسی",
#         "away_team": "لژیا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/418022/بازی-چلسی-لژیا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "هلند",
#         "away_team": "اسپانیا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414968/بازی-هلند-اسپانیا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "کرواسی",
#         "away_team": "فرانسه",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414969/بازی-کرواسی-فرانسه",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "دانمارک",
#         "away_team": "پرتغال",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414970/بازی-دانمارک-پرتغال",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ایتالیا",
#         "away_team": "آلمان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414971/بازی-ایتالیا-آلمان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اسپانیا",
#         "away_team": "هلند",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414972/بازی-اسپانیا-هلند",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "فرانسه",
#         "away_team": "کرواسی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414973/بازی-فرانسه-کرواسی",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "پرتغال",
#         "away_team": "دانمارک",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414974/بازی-پرتغال-دانمارک",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "آلمان",
#         "away_team": "ایتالیا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/414975/بازی-آلمان-ایتالیا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "استون ویلا",
#         "away_team": "لیورپول",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402823/بازی-استون-ویلا-لیورپول",
#         "video_link": "https://video.varzesh3.com/video/368775/خلاصه-بازی-استون-ویلا-2-لیورپول-2-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اورتون",
#         "away_team": "وستهم",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402825/بازی-اورتون-وستهم",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ایپسویچ",
#         "away_team": "ناتینگهام فارست",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402827/بازی-ایپسویچ-ناتینگهام-فارست",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "منچسترسیتی",
#         "away_team": "برایتون",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402829/بازی-منچسترسیتی-برایتون",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ساوتهمپتون",
#         "away_team": "ولورهمپتون",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402831/بازی-ساوتهمپتون-ولورهمپتون",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "بورنموث",
#         "away_team": "برنتفورد",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402824/بازی-بورنموث-برنتفورد",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "آرسنال",
#         "away_team": "چلسی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402822/بازی-آرسنال-چلسی",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "فولام",
#         "away_team": "تاتنهام",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402826/بازی-فولام-تاتنهام",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "لسترسیتی",
#         "away_team": "منچستر یونایتد",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402828/بازی-لسترسیتی-منچستر-یونایتد",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "نیوکسل",
#         "away_team": "کریستال پالاس",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/402830/بازی-نیوکسل-کریستال-پالاس",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "نساجی مازندران",
#         "away_team": "گل گهرسیرجان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417842/بازی-نساجی-مازندران-گل-گهرسیرجان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ملوان",
#         "away_team": "سپاهان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417841/بازی-ملوان-سپاهان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "صنعت نفت آبادان",
#         "away_team": "شهرداری نوشهر",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417840/بازی-صنعت-نفت-آبادان-شهرداری-نوشهر",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "استقلال",
#         "away_team": "پیکان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/417843/بازی-استقلال-پیکان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اسپانیا",
#         "away_team": "انگلیس",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/410074/بازی-اسپانیا-انگلیس",
#         "video_link": "https://video.varzesh3.com/video/347555/خلاصه-بازی-اسپانیا-2-انگلیس-1-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اردن",
#         "away_team": "قطر",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/399893/بازی-اردن-قطر",
#         "video_link": "https://video.varzesh3.com/video/324357/خلاصه-بازی-اردن-1-قطر-3"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "آرژانتین",
#         "away_team": "کلمبیا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/410123/بازی-آرژانتین-کلمبیا",
#         "video_link": "https://video.varzesh3.com/video/347571/خلاصه-بازی-آرژانتین-1-کلمبیا-0-گزارش-اختصاصی"
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ایران",
#         "away_team": "امارات",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/405970/بازی-ایران-امارات",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "ازبکستان",
#         "away_team": "قرقیزستان",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/405987/بازی-ازبکستان-قرقیزستان",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "قطر",
#         "away_team": "کره شمالی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/405986/بازی-قطر-کره-شمالی",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "پاراگوئه",
#         "away_team": "شیلی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/398291/بازی-پاراگوئه-شیلی",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "برزیل",
#         "away_team": "کلمبیا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/398289/بازی-برزیل-کلمبیا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "پرو",
#         "away_team": "بولیوی",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/398292/بازی-پرو-بولیوی",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اکوادور",
#         "away_team": "ونزوئلا",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/398290/بازی-اکوادور-ونزوئلا",
#         "video_link": null
#     },
#     {
#         "date": "پنج شنبه 23 اسفند",
#         "home_team": "اروگوئه",
#         "away_team": "آرژانتین",
#         "score": null,
#         "match_link": "https://www.varzesh3.com/football/match/398293/بازی-اروگوئه-آرژانتین",
#         "video_link": null
#     }
# ]
